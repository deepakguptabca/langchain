# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.14

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

# %% [markdown]
# ## genreative ai application using agents

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Why do parrots talk?")
print(response.content)
# Out:
# Parrots talk due to a fascinating combination of unique physical anatomy, high intelligence, and strong social instincts. Here's a breakdown of the key reasons:
#
# 1.  **Unique Vocal Anatomy (The "How"):**
#     *   **Syrinx:** Unlike humans who have a larynx (vocal cords), parrots have a highly complex vocal organ called a **syrinx** located at the base of their trachea. This syrinx allows them incredible control over pitch, tone, and rhythm, enabling them to produce a wide range of sounds.
#     *   **Tongue and Breath Control:** Parrots also have thick, muscular tongues and excellent breath control, which further aids in manipulating sounds to mimic human speech.
#
# 2.  **Vocal Learning (Brain Structure):**
#     *   Parrots belong to a select group of animals (including songbirds and hummingbirds) that possess **vocal learning** abilities. This means they can learn to produce new sounds by imitation, rather than being born with a fixed set of vocalizations.
#     *   Their brains have specialized **vocal learning centers** that are distinct from other parts of the brain controlling general motor skills. This neural circuitry is crucial for their ability to acquire and reproduce complex sounds.
#
# 3.  **Strong Social Drive (The "Why" in the Wild):**
#     *   **Flock Identity and Bonding:** In the wild, parrots are highly social creatures that live in large flocks. Mimicry plays a crucial role in their natural communication. They learn specific calls and vocalizations from their flock members to identify each other, maintain group cohesion, and communicate warnings or food sources.
#     *   **Adaptation:** Being able to learn and adapt their calls helps them fit into new social groups or respond to changes in their environment.
#
# 4.  **Social Drive (The "Why" with Humans):**
#     *   **Humans as their "Flock":** When parrots are kept as pets, humans become their primary social group, their "flock." They are driven to communicate and bond with their human companions.
#     *   **Attention and Interaction:** Talking is a highly effective way for parrots to get attention and interact with their human caregivers. When a parrot says something and gets a positive reaction (laughter, praise, a treat), it reinforces the behavior, encouraging them to talk more.
#     *   **Mimicking Environmental Sounds:** Parrots are naturally inclined to mimic sounds in their environment. In a human household, human speech is a dominant sound, so they naturally attempt to reproduce it.
#
# 5.  **Intelligence and Cognitive Ability:**
#     *   Parrots, particularly species like African Greys and Amazons, are highly intelligent animals. They have excellent problem-solving skills and a remarkable capacity for learning. Talking can be seen as a form of cognitive engagement for them.
#     *   **Contextual Understanding (not semantic):** While parrots don't understand the *meaning* of words in the same abstract way humans do, they are excellent at associating sounds with specific contexts. For example, a parrot might learn to say "Hello" when someone enters the room, or "Want a cracker?" when it's hungry and sees its owner near the treat jar. They learn *associations* between sounds and events/rewards.
#
# **In summary:** Parrots talk because they have the physical apparatus and brainpower for vocal learning, and a profound social need to communicate and bond with their flock, whether that flock consists of other parrots or humans. Their talking is a testament to their intelligence and their deeply social nature.
