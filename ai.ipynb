# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.14

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

# %% [markdown]
# ## genreative ai application using agents

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Why do parrots talk?")
print(response.content)
# Out:
# Parrots talk primarily due to a unique combination of **biology, social behavior, and intelligence**. It's important to clarify that while they "talk," they don't understand language in the same way humans do.
#
# Here's a breakdown of the reasons:
#
# 1.  **Unique Vocal Anatomy (The Syrinx):**
#     *   Unlike humans who use a larynx, birds have a **syrinx** – their voice box. The syrinx in parrots is highly complex and flexible.
#     *   It allows them to produce a wide range of sounds, including those with varying pitch, tone, and rhythm, which are necessary to mimic human speech.
#     *   Their thick, muscular tongue also plays a role in manipulating sounds.
#
# 2.  **Specialized Brain Structures for Vocal Learning:**
#     *   Parrots, along with songbirds and hummingbirds, are one of the few groups of animals capable of **vocal learning**. This means they can learn and produce new sounds by imitation, rather than just relying on innate calls.
#     *   Their brains have specific "vocal learning cores" (like "song nuclei" in songbirds) that are more developed and complex, enabling them to mimic a vast array of sounds, including human words.
#
# 3.  **Strong Social Drive and Flock Behavior:**
#     *   Parrots are highly social animals that live in flocks in the wild. Vocal communication is crucial for maintaining flock cohesion, identifying individuals, warning of predators, and sharing information.
#     *   When a parrot lives with humans, it often considers its human companions its "flock." It has a strong desire to communicate and bond with its flock members.
#
# 4.  **Mimicry as a Survival and Bonding Tool (in the wild and captivity):**
#     *   **In the Wild:** Parrots naturally mimic other birds, animals, and environmental sounds in their habitat. This can help them blend in, avoid predators, or communicate more effectively within their diverse environment.
#     *   **In Captivity:** When living with humans, they perceive human speech as the dominant "language" of their new flock. Mimicking these sounds is a way for them to:
#         *   **Fit in:** They try to replicate the sounds of their environment and their flock members.
#         *   **Seek Attention:** Saying words or phrases often elicits a reaction from humans (excitement, praise, treats), which reinforces the behavior.
#         *   **Bond:** It's a form of interaction and connection with their human companions.
#         *   **Communicate Needs:** While they don't understand the *meaning* of "Want a cracker," they learn to associate the phrase with the *outcome* of getting a cracker. So, they learn to use specific sounds to get what they want.
#
# 5.  **Intelligence and Associative Learning:**
#     *   Parrots are intelligent birds. While they don't grasp abstract language, they are very good at **associative learning**. They can link sounds (words) to specific objects, actions, people, or contexts.
#     *   For example, an African Grey parrot might learn to say "Hello" when someone enters the room, or "Bye-bye" when someone leaves, associating the sound with the event rather than understanding the literal meaning of the words.
#
# In summary, parrots talk because they possess the unique biological hardware (syrinx, specialized brain structures) for vocal learning, are highly social animals driven to communicate with their flock, and are intelligent enough to associate specific sounds with outcomes or contexts. They are not "understanding" language like a human child, but rather are incredibly skilled mimics and associative learners.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model=ChatGoogleGenerativeAI(model="gemini-2.5-flash")
response=model.invoke("Why do parrots talk?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
#       2 model=ChatGoogleGenerativeAI(model="gemini-2.5-flash")
# ----> 3 response=model.invoke("Why do parrots talk?")
#       4 print(response)
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\langchain_google_genai\chat_models.py:2791, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2788         msg = "Tools are already defined.code_execution tool can't be defined"
#    2789         raise ValueError(msg)
# -> 2791 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)
#     469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)
#    1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\langchain_google_genai\chat_models.py:3379, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3366 request = self._prepare_request(
#    3367     messages,
#    3368     stop=stop,
#    (...)
#    3376     **kwargs,
#    3377 )
#    3378 try:
# -> 3379     response: GenerateContentResponse = self.client.models.generate_content(
#    3380         **request,
#    3381     )
#    3382 except ClientError as e:
#    3383     _handle_client_error(e, request)
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\google\genai\models.py:6604, in Models.generate_content(self, model, contents, config)
#    6598   parsed_config_to_call = _extra_utils.get_usage_header(
#    6599       parsed_config_to_call,
#    6600       types.GenerateContentConfig,
#    6601       'afc',
#    6602   )
#    6603 i += 1
# -> 6604 response = self._generate_content(
#    6605     model=model, contents=contents, config=parsed_config_to_call
#    6606 )
#    6608 if not function_map:
#    6609   break
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\google\genai\models.py:5028, in Models._generate_content(self, model, contents, config)
#    5025 request_dict = _common.convert_to_dict(request_dict)
#    5026 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5028 response = self._api_client.request(
#    5029     'post', path, request_dict, http_options
#    5030 )
#    5032 if config is not None and getattr(
#    5033     config, 'should_return_http_response', None
#    5034 ):
#    5035   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\google\genai\_api_client.py:1708, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1698 def request(
#    1699     self,
#    1700     http_method: str,
#    (...)
#    1703     http_options: Optional[HttpOptionsOrDict] = None,
#    1704 ) -> SdkHttpResponse:
#    1705   http_request = self._build_request(
#    1706       http_method, path, request_dict, http_options
#    1707   )
# -> 1708   response = self._request(http_request, http_options, stream=False)
#    1709   response_body = (
#    1710       response.response_stream[0] if response.response_stream else ''
#    1711   )
#    1712   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\google\genai\_api_client.py:1493, in BaseApiClient._request(self, http_request, http_options, stream)
#    1491     retry_kwargs = retry_args(parameter_model.retry_options)
#    1492     retry = tenacity.Retrying(**retry_kwargs)
# -> 1493     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1495 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\google\genai\_api_client.py:1471, in BaseApiClient._request_once(self, http_request, stream)
#    1463 else:
#    1464   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1465       method=http_request.method,
#    1466       url=http_request.url,
#    (...)
#    1469       timeout=http_request.timeout,
#    1470   )
# -> 1471   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
#    1472 errors.APIError.raise_for_response(response)
#    1473 return HttpResponse(
#    1474     response.headers, response if stream else [response.text]
#    1475 )
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\Deepak Gupta\Desktop\codes\RAG\.venv\lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ### streaming

# %%
model.invoke("Write 500 words paragraph on AI")
# Out:
# AIMessage(content='Artificial Intelligence (AI) represents humanity\'s ambitious quest to imbue machines with cognitive abilities traditionally associated with the human mind, evolving from nascent theoretical foundations in the mid-20th century into an omnipresent force shaping our daily lives. Today, the most prevalent form is "narrow AI" or "weak AI," excelling at specific tasks without possessing general human-like intelligence. This sophisticated narrow AI powers the recommendation engines that curate our entertainment on platforms like Netflix and Spotify, the voice assistants like Siri and Alexa that answer our queries, the fraud detection systems safeguarding our financial transactions, and the advanced algorithms optimizing supply chains and traffic flow. Its impact is profoundly felt across diverse sectors: in healthcare, AI assists in diagnosing diseases with remarkable accuracy from medical images, accelerates drug discovery, and personalizes treatment plans; in transportation, it is the bedrock of autonomous vehicles, promising safer and more efficient travel; in finance, it performs complex market analysis and algorithmic trading; and in manufacturing, it optimizes production lines and predictive maintenance.\n\nThe engine driving this transformation is primarily machine learning, a subset of AI that enables systems to learn from data without explicit programming. Deep learning, a further specialization utilizing artificial neural networks with multiple layers, has unlocked unprecedented capabilities in pattern recognition, natural language processing, and computer vision, allowing machines to understand, interpret, and generate human-like text, speech, and images. The confluence of vast datasets, immense computational power, and refined algorithms has propelled AI into an era of rapid innovation, enabling breakthroughs that were once confined to science fiction. However, this revolutionary potential is inextricably linked with a complex array of ethical, social, and economic challenges. Concerns around data privacy, algorithmic bias, and the potential for job displacement demand careful consideration and proactive governance. The "black box" problem, where the decision-making processes of complex AI models are opaque, raises questions of accountability and trust, particularly in critical applications like criminal justice or autonomous weapon systems. Ensuring fairness, transparency, and human oversight in AI development is paramount to prevent the perpetuation or amplification of societal inequalities.\n\nLooking ahead, the pursuit of Artificial General Intelligence (AGI), machines capable of performing any intellectual task a human can, remains a distant but captivating goal, prompting profound philosophical and practical debates about consciousness, control, and humanity\'s role in a world potentially shared with superintelligent entities. Yet, even as we ponder these far-reaching possibilities, the immediate future of AI lies in its role as a powerful augmentative tool, designed to enhance human capabilities rather than replace them. It promises to liberate us from mundane tasks, amplify our creativity, accelerate scientific discovery, and help us tackle some of the world\'s most pressing problems, from climate change to global pandemics. The symbiotic relationship between human ingenuity and artificial intelligence holds the key to unlocking unprecedented levels of productivity, innovation, and societal progress. Therefore, navigating the future of AI requires a collaborative, multidisciplinary approach, one that prioritizes responsible innovation, ethical design, and inclusive development, ensuring that this transformative technology serves humanity\'s best interests and fosters a future where intelligence, both human and artificial, thrives in harmony.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai ...

# %%
for chunk in model.stream("Write a 500 words paragraph on AI"):
    print(chunk,end="| ",flush=True)
# Out:
# content='Artificial Intelligence, or AI, stands as one of the most profound technological revolutions of our era, reshaping industries, economies, and the very fabric of daily life. At its core, AI refers' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a00485-c49b-71e0-a98a-ee6c0c62c345' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 11, 'output_tokens': 1580, 'total_tokens': 1591, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1542}} tool_call_chunks=[]| content=' to the development of computer systems capable of performing tasks that typically require human intelligence, encompassing learning, reasoning, problem-solving, perception, and language understanding. From its nascent theoretical roots in the mid-20th century to the sophisticated deep' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a00485-c49b-71e0-a98a-ee6c0c62c345' tool_calls=[] invalid_tool_calls=[] usage_metadata={'output_token_details': {'reasoning': 0}, 'output_tokens': 48, 'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 48} tool_call_chunks=[]| content=' learning models of today, AI has evolved from a futuristic concept into an omnipresent reality. Its applications are startlingly diverse and often seamlessly integrated into our routines: the personalized recommendations from streaming services, the voice assistants on our smartphones, the intricate algorithms powering' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a00485-c49b-71e0-a98a-ee6c0c62c345' tool_calls=[] invalid_tool_calls=[] usage_metadata={'output_token_details': {'reasoning': 0}, 'output_tokens': 50, 'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 50} tool_call_chunks=[]| content=' search engines, and the advanced diagnostics aiding medical professionals. AI-driven systems are optimizing supply chains, detecting financial fraud, designing new materials, and even composing music and generating art. In domains like healthcare, AI is accelerating drug discovery, refining' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a00485-c49b-71e0-a98a-ee6c0c62c345' tool_calls=[] invalid_tool_calls=[] usage_metadata={'output_token_details': {'reasoning': 0}, 'output_tokens': 48, 'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 48} tool_call_chunks=[]| content=' surgical procedures, and providing early disease detection, promising a future of more personalized and effective treatment. Autonomous vehicles, though still evolving, represent another frontier, aiming to revolutionize transportation and urban planning.\n\nThe transformative power of AI lies in its capacity' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a00485-c49b-71e0-a98a-ee6c0c62c345' tool_calls=[] invalid_tool_calls=[] usage_metadata={'output_token_details': {'reasoning': 0}, 'output_tokens': 48, 'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 48} tool_call_chunks=[]| content=' for unparalleled efficiency, precision, and scalability. It can process vast datasets at speeds impossible for humans, uncover hidden patterns, and make predictions with remarkable accuracy, thereby driving innovation and productivity across virtually every sector. This analytical prowess is not merely about' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a00485-c49b-71e0-a98a-ee6c0c62c345' tool_calls=[] invalid_tool_calls=[] usage_metadata={'output_token_details': {'reasoning': 0}, 'output_tokens': 48, 'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 48} tool_call_chunks=[]| content=" automation; it's about  ...

# %% [markdown]
# # batching

# %%
responses = model.batch(
    [
        "why do parrots have colorful feathers?",
        "why do airplanes fly?",
        "what is quantum computing?",
    ]
)

for response in responses:
    print(response)
# Out:
# content='Parrots have colorful feathers for a combination of fascinating evolutionary and biological reasons:\n\n1.  **Sexual Selection (Attracting Mates):** This is arguably the primary driver.\n    *   **Sign of Health and Fitness:** Bright, vibrant plumage signals to potential mates that a parrot is healthy, well-nourished, and has good genes. Producing and maintaining such elaborate coloration requires energy and access to specific nutrients (like carotenoids from their diet). A dull or faded parrot might indicate illness or poor foraging ability, making them less attractive.\n    *   **Display:** Many parrot species engage in elaborate courtship displays where they show off their feathers, further emphasizing their vibrancy.\n\n2.  **Species Recognition:**\n    *   In environments with multiple similar parrot species, distinct color patterns help individuals recognize members of their own species. This prevents interbreeding and ensures successful reproduction within their own kind.\n\n3.  **Camouflage (Counter-intuitive but true):**\n    *   While they seem incredibly bright to human eyes in a plain setting, in their natural habitats (dense, brightly lit rainforests with dappled sunlight, colorful fruits, flowers, and leaves), their vibrant plumage can surprisingly blend in.\n    *   Think of a macaw in a canopy full of red, yellow, and green fruits and leaves – the broken patterns of light and shadow, combined with the riot of natural colors, can make a bright parrot surprisingly difficult to spot.\n\n4.  **Signaling and Communication:**\n    *   Colors can also play a role in social signaling within a flock, indicating dominance, mood, or other messages.\n\n5.  **Diet and Pigmentation (The "How"):** The ability to produce these colors comes from two main sources:\n    *   **Pigments:**\n        *   **Psittacofulvins:** These are unique pigments found only in parrots, responsible for many of their brilliant reds, oranges, and yellows. Parrots can synthesize these pigments themselves.\n        *   **Carotenoids:** Parrots obtain these yellow and red pigments from their diet (fruits, vegetables, seeds). A diet rich in carotenoids contributes to brighter plumage.\n        *   **Melanins:** These pigments produce black, brown, and gray colors.\n    *   **Structural Colors:** Blues and greens, and iridescent effects, are often not due to pigments but to the microscopic structure of the feathers. These structures scatter and reflect specific wavelengths of light, creating the perception of blue or green. This is why you often see blue and green parrots, even though there aren\'t many naturally blue or green foods for them to eat to get those colors from pigments.\n\nIn summary, the dazzling array of colors in parrots is a powerful evolutionary tool, primarily driven by the need to attract mates and signal fitness, while also serving roles in species recognition and even camouflage within their vibrant ecosystems.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a00493-e5f4-7311-a548-572ac7fdf7e2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 1603, 'total_tokens': 1611, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1011}}
# content='Airplanes fly due to a fascinating interplay of four fundamental forces: **Lift, Thrust, Drag, and Weight (Gravity).** For an airplane to fly, these forces must be carefully balanced and manipulated.\n\nHere\'s a breakdown of each force and how they work together:\n\n1.  **Lift:**\n    *   **What it is:** The upward force that directly opposes the weight of the aircraft, keeping it in the air.\n    *   **How it\'s generated:** Primarily by the **wings**, which are specially shaped airfoils.\n        *   **Airfoil Shape:** The top surface of a wing is curved, while the bottom is flatter. As the wing moves through the air, air flowing over the curved top has to travel a greater distance in the same amount of time, so it speeds up. According to **Bernoulli\'s Principle**, faster-moving air has lower pressure. The air flowing under the flatter bottom moves slower, creating higher pressure. This pressure difference (higher pressure below, lower pressure above) creates an upward push, or lift.\n        *   **Angle of Attack (Newton\'s Third Law):** The wing is also tilted slightly upwards relative to the oncoming air (this is called the angle of attack). As the wing pushes air downwards, the air pushes the wing upwards with an equal and opposite force.\n    *   **Key factors:** Speed of the aircraft, shape of the wing, and the angle at which the wing meets the air.\n\n2.  **Thrust:**\n    *   **What it is:** The forward force that propels the aircraft through the air, overcoming drag.\n    *   **How it\'s generated:** By the **engines**.\n        *   **Jet Engines:** Suck in air, compress it, mix it with fuel and ignite it, then expel hot, high-velocity gases out the back. This powerful backward push creates a forward thrust (Newton\'s Third Law: "For every action, there is an equal and opposite reaction").\n        *   **Propeller Engines:** The propellers are like rotating wings. They spin, pulling air from in front and pushing it backward, creating a forward pulling force on the aircraft.\n\n3.  **Drag:**\n    *   **What it is:** The resistance force that opposes the aircraft\'s motion through the air. It\'s essentially air friction.\n    *   **How it\'s generated:** By the air molecules rubbing against the aircraft\'s surfaces and by the disruption of airflow around the aircraft\'s shape.\n    *   **Key factors:** The shape of the aircraft (aerodynamic design minimizes drag), its speed, and the density of the air.\n\n4.  **Weight (Gravity):**\n    *   **What it is:** The downward force pulling the aircraft towards the Earth.\n    *   **How it\'s generated:** By the force of gravity acting on the entire mass of the aircraft (its structure, fuel, passengers, cargo).\n\n**How they work together for flight:**\n\n*   **Takeoff:** The engines generate enough **thrust** to accelerate the plane to a speed where the wings can generate sufficient **lift** to overcome the **weight** of the aircraft.\n*   **Level Flight:** For an airplane to maintain a constant altitude and speed, **lift** must equal **weight**, and **thrust** must equal **drag**.\n*   **Climbing:** The pilot increases thrust and/or the angle of attack of the wings, causing lift to be greater than weight and/or thrust to be greater than drag, resulting in an upward and/or forward acceleration.\n*   **Descending:** The pilot reduces thrust and/or the angle of attack, causing lift to be less than weight, allowing the plane to lose altitude.\n\nIn essence, airplanes fly because their powerful engines create enough thrust to move them fast enough for their specially designed wings to generate enough lift to overcome gravity, all while minimizing the opposing force of drag. It\'s a marvel of physics and engineering!' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a00493-e5fc-70b3-b58b-8af9b23d2098-0' tool_calls=[] invalid_tool_calls=[] usage_metadata ...
# content='Quantum computing is a revolutionary new type of computing that leverages the principles of **quantum mechanics** (the physics that governs the universe at a subatomic level) to perform calculations.\n\nUnlike classical computers, which store information in bits that can be either a 0 or a 1, quantum computers use **qubits**.\n\nHere\'s a breakdown of the core concepts:\n\n1.  **Qubits (Quantum Bits):**\n    *   A classical bit is like a light switch: it\'s either ON (1) or OFF (0).\n    *   A qubit is like a spinning coin: while it\'s spinning, it\'s simultaneously heads and tails. Only when it stops and you observe it does it settle into one state. This allows qubits to hold much more information than classical bits.\n\n2.  **Superposition:**\n    *   This is the "spinning coin" property. A qubit can exist in a combination of 0 and 1 at the same time. This means that a quantum computer can explore many possibilities simultaneously, rather than sequentially.\n    *   For example, two classical bits can be in one of four states (00, 01, 10, 11) at any given time. Two qubits, thanks to superposition, can be in *all four states simultaneously*.\n\n3.  **Entanglement:**\n    *   This is an even stranger quantum phenomenon. When qubits are entangled, they become linked in such a way that the state of one instantly influences the state of the others, no matter how far apart they are.\n    *   Imagine you have two entangled coins. If you flip one and it lands heads, you instantly know the other one *must* be tails (or vice-versa, depending on how they were entangled), even if you haven\'t looked at it yet.\n    *   Entanglement allows quantum computers to perform incredibly complex calculations and find relationships between data points that would be impossible for classical computers.\n\n**How it Works (Simplified):**\n\nQuantum computers manipulate qubits using precise lasers, microwaves, or magnetic fields to set them into superposition and entangle them. They then run a series of quantum operations (a "quantum algorithm") before measuring the final state of the qubits. Because of the probabilistic nature of quantum mechanics, the process often needs to be repeated many times to get a reliable answer.\n\n**Why is it Powerful?**\n\nThe combination of superposition and entanglement allows quantum computers to process vast amounts of information and explore many solutions to a problem simultaneously. This gives them the potential to solve certain types of problems that are practically impossible for even the most powerful classical supercomputers.\n\n**Potential Applications:**\n\n*   **Drug Discovery & Materials Science:** Simulating complex molecules and chemical reactions to design new medicines, catalysts, or advanced materials.\n*   **Cryptography:** Breaking currently used encryption methods (like RSA) and developing new, unhackable quantum-resistant encryption.\n*   **Optimization:** Finding the best solutions for complex logistics, financial modeling, traffic flow, or supply chain problems.\n*   **Artificial Intelligence & Machine Learning:** Enhancing AI algorithms for pattern recognition, data analysis, and learning.\n*   **Financial Modeling:** More accurate risk analysis and market prediction.\n\n**Current Status:**\n\nQuantum computing is still in its early stages. While significant progress has been made in building and operating small-scale quantum computers, they are experimental and prone to errors. They are not designed to replace classical computers for everyday tasks like browsing the internet or word processing. Instead, they are specialized tools being developed to tackle specific, extremely challenging computational problems.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a00493-e607-7521-afae-c87af93f33be-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, ' ...
